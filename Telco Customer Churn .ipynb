# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv('telco.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7049 non-null   object
#  1   gender             7049 non-null   object
#  2   is_senior_citizen  7049 non-null   int64
#  3   partner            7049 non-null   object
#  4   dependents         7049 non-null   object
#  5   phone_service      7049 non-null   int64
#  6   internet_service   7049 non-null   int64
#  7   contract_type      7049 non-null   int64
#  8   payment_type       7049 non-null   object
#  9   monthly_charges    7049 non-null   float64
#  10  total_charges      7038 non-null   float64
#  11  churn              7049 non-null   object
#  12  tenure             7049 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 716.0+ KB

# %%
df.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7049.000000    7049.000000       7049.000000    7049.000000
# mean            0.162009       1.324585          1.222585       0.690878
# std             0.368485       0.642709          0.779068       0.833757
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_charges  total_charges       tenure
# count      7049.000000    7038.000000  7049.000000
# mean         64.747014    2283.043883    32.380068
# std          30.099460    2266.521984    24.594926
# min          18.250000      18.800000     0.000000
# 25%          35.450000     401.587500     8.700000
# ...

# %%
df.isna().sum()
# Out:
# customer_id           0
# gender                0
# is_senior_citizen     0
# partner               0
# dependents            0
# phone_service         0
# internet_service      0
# contract_type         0
# payment_type          0
# monthly_charges       0
# total_charges        11
# churn                 0
# tenure                0
# dtype: int64

# %%
df2=df.dropna(how='any',subset=['total_charges'])

# %%
df2.isna().sum()
# Out:
# customer_id          0
# gender               0
# is_senior_citizen    0
# partner              0
# dependents           0
# phone_service        0
# internet_service     0
# contract_type        0
# payment_type         0
# monthly_charges      0
# total_charges        0
# churn                0
# tenure               0
# dtype: int64

# %%
df2.shape
# Out:
# (7038, 13)

# %% [markdown]
# df3.isna().sum()

# %%
df3=df.dropna()

# %%
#plot style
plt.style.use("fivethirtyeight")

# %%
# Churn 
ax = sns.countplot(x=df['churn'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('Churn')
ax.set_title('Churn Distribution')
plt.show()

# %%
# Gender
ax = sns.countplot(x=df['gender'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('Gender')
ax.set_title('Gender Distribution')
plt.show()

# %%
# Across Genders
ax = sns.countplot(x=df['gender'], hue =df['churn'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('Gender')
ax.set_title('Churn across Genders')
plt.show()

# %%
# Senior citizens
ax = sns.countplot(x=df['is_senior_citizen'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('Senior Citizen')
ax.set_title('Senior Citizen Distribution')
plt.show()
# 0=no 1=yes

# %%
#Churn across senior citizens 

ax= sns.countplot(x=df['is_senior_citizen'], hue=df['churn'], data=df)
plt.show()

# %%
# Dependents
ax = sns.countplot(x=df['dependents'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('Dependents')
ax.set_title('Dependents Distribution')
plt.show()
# 0=no 1=yes

# %%
# Churn across Dependents 
ax= sns.countplot(x=df['dependents'], hue=df['churn'], data=df)
plt.show()

# %%
# Partner
ax = sns.countplot(x=df['partner'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('partner')
ax.set_title('Partner Distribution')
plt.show()
# 0=no 1=yes

# %%
# Churn across partners
ax= sns.countplot(x=df['partner'], hue=df['churn'], data=df)
plt.show()

# %%
# Internet Service Type 
ax = sns.countplot(x=df['internet_service'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('internet service')
ax.set_title('Internet Service  Distribution')
plt.show()
# 0=no 1=yes

# %%
# Churn across Internet service 
ax= sns.countplot(x=df['internet_service'], hue=df['churn'], data=df)
plt.show()

#None DSL Fiber Optic

# %%
# Contract Types 
ax = sns.countplot(x=df['contract_type'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('contract')
ax.set_title('contract  Distribution')
plt.show()
# 0=no 1=yes

# %%
# Churn across contract types 
ax= sns.countplot(x=df['contract_type'], hue=df['churn'], data=df)
plt.show()

# %%
# Payment Type 
ax = sns.countplot(x=df['payment_type'], data=df)
ax.set_ylabel('Number of Customers')
ax.set_xlabel('payment type')
ax.set_title('contract  Distribution')
plt.show()
# 0=no 1=yes

# %%
# Churn across payment types 
ax= sns.countplot(x=df['payment_type'], hue=df['churn'], data=df)
plt.show()

# %%
# plot of tenure month  vs. churn 
ax=sns.boxplot(x=df['churn'], y=df['tenure'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plot of monthly charges  vs. churn 
ax=sns.boxplot(x=df['churn'], y=df['monthly_charges'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
 # plot of total charges vs. churn 
ax=sns.boxplot(x=df['churn'], y=df['total_charges'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
